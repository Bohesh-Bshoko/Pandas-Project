# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **TED DataFrame**

# %%
url = 'https://drive.google.com/file/d/1tT58DQkKaLHKcinMa5JVFBd4bdCVQd1X/view'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)

# %%
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %% [markdown]
# # **תרגיל 1**

# %%
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df.shape[0]
# Out:
# 2550

# %% [markdown]
# # **תרגיל 2**

# %%
df[['title','views']]
# Out:
#                                                   title     views
# 0                           Do schools kill creativity?  47227110
# 1                           Averting the climate crisis   3200520
# 2                                      Simplicity sells   1636292
# 3                                   Greening the ghetto   1697550
# 4                       The best stats you've ever seen  12005869
# ...                                                 ...       ...
# 2545  What we're missing in the debate about immigra...    450430
# 2546                    The most Martian place on Earth    417470
# 2547  What intelligent machines can learn from a sch...    375647
# 2548       A black man goes undercover in the alt-right    419309
# 2549  How a video game might help us build better ci...    391721
#
# [2550 rows x 2 columns]

# %%
df[df['event'] == 'TED2006']
# Out:
#      comments                                        description  duration  \
# 0        4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1         265  With the same humor and humanity he exuded in ...       977
# 2         124  New York Times columnist David Pogue takes aim...      1286
# 3         200  In an emotionally charged talk, MacArthur-winn...      1116
# 4         593  You've never seen data presented like this. Wi...      1190
# 5         672  Tony Robbins discusses the "invisible forces" ...      1305
# 6         919  When two young Mormon missionaries knock on Ju...       992
# 7          46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8         852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9         900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10         79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
df[df['views'] > 10000000]
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 29         970  Dan Gilbert, author of "Stumbling on Happiness...      1276
# 30         991  Psychologist Barry Schwartz takes aim at a cen...      1177
# 47         578  Why do people succeed? Is it because they're s...       210
# 176        554  David Gallo shows jaw-dropping footage of amaz...       327
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 262        669  First, Keith Barry shows us how our brains can...      1189
# 381       1604  Elizabeth Gilbert muses on the impossible thin...      1149
# 452        354  "Bonk" author Mary Roach delves into obscure s...      1003
# ...

# %%
df[(df['event'] == 'TED2006') & (df['views'] > 10000000)]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 4       593  You've never seen data presented like this. Wi...      1190
# 5       672  Tony Robbins discusses the "invisible forces" ...      1305
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 4  TED2006  1140566400         48  Hans Rosling
# 5  TED2006  1138838400         36  Tony Robbins
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
# 5             Tony Robbins: Why we do what we do            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# ...

# %% [markdown]
# # **תרגיל 3**

# %%
df[['views']].mean(axis=0)
# Out:
# views    1.698297e+06
# dtype: float64

# %%
df[df['event'] == 'TED2006'][['views']].mean(axis=0)
# Out:
# views    3.274345e+06
# dtype: float64

# %%
df[['duration']].mean(axis=0)
# Out:
# duration    826.510196
# dtype: float64

# %%
df[df['event'] == 'TED2006'][['duration']].mean(axis=0)
# Out:
# duration    982.577778
# dtype: float64

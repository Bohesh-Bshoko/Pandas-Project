# %% [markdown]
# # Exercise2 - תרגיל2
# *   NOTICE: do not run/change the Questions ! לא לשנות את השאלות
# *   NOTICE: do not change Output Examples ! לא לשנות את הדוגמאות
# *   Your Task: Just change the **"put your code here"** sections

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[11,11,13,14,13,13],
                   'B':[np.nan,22,23,24,np.nan,26],
                   'C':[31,32,33,34,np.nan,36],
                   'D':[41,42,43,44,45,np.nan],
                   'E':[51,52,53,54,55,np.nan]
                   })

# %%
df
# Out:
#     A     B     C     D     E
# 0  11   NaN  31.0  41.0  51.0
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 3  14  24.0  34.0  44.0  54.0
# 4  13   NaN   NaN  45.0  55.0
# 5  13  26.0  36.0   NaN   NaN

# %%
df.dropna()
# Out:
#     A     B     C     D     E
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 3  14  24.0  34.0  44.0  54.0

# %%
# הסרת שורות עם ערכים חסרים
# Out:
#     A     B     C     D     E
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 3  14  24.0  34.0  44.0  54.0

# %%
df.dropna(axis=1)
# Out:
#     A
# 0  11
# 1  11
# 2  13
# 3  14
# 4  13
# 5  13

# %%
# הסרת עמודות עם ערכים חסרים
# Out:
#     A
# 0  11
# 1  11
# 2  13
# 3  14
# 4  13
# 5  13

# %%
df.dropna(thresh=5 ,axis=1)
# Out:
#     A     C     D     E
# 0  11  31.0  41.0  51.0
# 1  11  32.0  42.0  52.0
# 2  13  33.0  43.0  53.0
# 3  14  34.0  44.0  54.0
# 4  13   NaN  45.0  55.0
# 5  13  36.0   NaN   NaN

# %%
# הסר עמודות שאין להם לפחות 5 ערכים תקינים
# hint: use thresh parameter
# Out:
#     A     C     D     E
# 0  11  31.0  41.0  51.0
# 1  11  32.0  42.0  52.0
# 2  13  33.0  43.0  53.0
# 3  14  34.0  44.0  54.0
# 4  13   NaN  45.0  55.0
# 5  13  36.0   NaN   NaN

# %%
df
# Out:
#     A     B     C     D     E
# 0  11   NaN  31.0  41.0  51.0
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 3  14  24.0  34.0  44.0  54.0
# 4  13   NaN   NaN  45.0  55.0
# 5  13  26.0  36.0   NaN   NaN

# %%
df.fillna(value="*")
# Out:
#     A     B     C     D     E
# 0  11     *  31.0  41.0  51.0
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 3  14  24.0  34.0  44.0  54.0
# 4  13     *     *  45.0  55.0
# 5  13  26.0  36.0     *     *

# %%
# fill * on missing values
# Out:
#     A     B     C     D     E
# 0  11     *  31.0  41.0  51.0
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 3  14  24.0  34.0  44.0  54.0
# 4  13     *     *  45.0  55.0
# 5  13  26.0  36.0     *     *

# %%
df['B'].fillna(value="*")
# Out:
# 0       *
# 1    22.0
# 2    23.0
# 3    24.0
# 4       *
# 5    26.0
# Name: B, dtype: object

# %%
# fill * on missing values column B
# Out:
# 0       *
# 1    22.0
# 2    23.0
# 3    24.0
# 4       *
# 5    26.0
# Name: B, dtype: object

# %%
df.fillna(df.mean())
# Out:
#     A      B     C     D     E
# 0  11  23.75  31.0  41.0  51.0
# 1  11  22.00  32.0  42.0  52.0
# 2  13  23.00  33.0  43.0  53.0
# 3  14  24.00  34.0  44.0  54.0
# 4  13  23.75  33.2  45.0  55.0
# 5  13  26.00  36.0  43.0  53.0

# %%
# שים במקום ערכים חסרים את הממוצע של הטור
# Out:
#     A      B     C     D     E
# 0  11  23.75  31.0  41.0  51.0
# 1  11  22.00  32.0  42.0  52.0
# 2  13  23.00  33.0  43.0  53.0
# 3  14  24.00  34.0  44.0  54.0
# 4  13  23.75  33.2  45.0  55.0
# 5  13  26.00  36.0  43.0  53.0

# %%
df
# Out:
#     A     B     C     D     E
# 0  11   NaN  31.0  41.0  51.0
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 3  14  24.0  34.0  44.0  54.0
# 4  13   NaN   NaN  45.0  55.0
# 5  13  26.0  36.0   NaN   NaN

# %%
df.groupby('A').sum()
# Out:
#        B     C     D      E
# A
# 11  22.0  63.0  83.0  103.0
# 13  49.0  69.0  88.0  108.0
# 14  24.0  34.0  44.0   54.0

# %%
# Group and Sum by column A
# Out:
#        B     C     D      E
# A
# 11  22.0  63.0  83.0  103.0
# 13  49.0  69.0  88.0  108.0
# 14  24.0  34.0  44.0   54.0

# %%
df['A'].unique()
# Out:
# array([11, 13, 14])

# %%
# Display unique values on column A
# Out:
# array([11, 13, 14])

# %%
df['A'].nunique()
# Out:
# 3

# %%
# How many unique values on column A
# Out:
# 3

# %%
df['A'].value_counts()
# Out:
# 13    3
# 11    2
# 14    1
# Name: A, dtype: int64

# %%
# How many per group in column A (value_counts)
# Out:
# 13    3
# 11    2
# 14    1
# Name: A, dtype: int64

# %%
df['B'].max()
# Out:
# 26.0

# %%
# find maximum in column B
# Out:
# 26.0

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
#display column names
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.sort_values(by='A')
# Out:
#     A     B     C     D     E
# 0  11   NaN  31.0  41.0  51.0
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 4  13   NaN   NaN  45.0  55.0
# 5  13  26.0  36.0   NaN   NaN
# 3  14  24.0  34.0  44.0  54.0

# %%
#sort according to values in column A
# Out:
#     A     B     C     D     E
# 0  11   NaN  31.0  41.0  51.0
# 1  11  22.0  32.0  42.0  52.0
# 2  13  23.0  33.0  43.0  53.0
# 4  13   NaN   NaN  45.0  55.0
# 5  13  26.0  36.0   NaN   NaN
# 3  14  24.0  34.0  44.0  54.0
